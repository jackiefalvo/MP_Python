# %% [markdown]
# This Script:
# - brings in **acoustic data**
#     - explodes between days
# - makes a **test date range** (Jan 1 - Feb 28 2011)
# - left joins (cleaned, less columns) acoustic data to test date range --> **Acou_JanFeb**
# - creates **fake prey data**
# - left joins **fake prey data** to **Acou_JanFeb** --> **CCB_JanFeb**
# - made some plots of Jan/Feb
# - attempted to create new column that describes data availability/overlap

# %%
import pandas as pd
import altair as alt
import os
import numpy as np

# %%
os.chdir('/Users/cristiana/Documents/Duke/MP/Python')

# %%
# read in CCB Acoustic metadata, parse date columns
ccb = pd.read_csv('./Data/CCB Metadata.csv', 
                 sep=',', 
                 encoding='utf-8',
                 parse_dates = ['deployDate','recoveryDate'])

ccb.head()
# Out:
#    c_recordOnDays                                     c_uniqueUnitID  \
# 0              71  2011_BRP_CCB_S1016_Dep20_20110217_PU0205_FD020...
# 1              80  2011_BRP_CCB_S1016_Dep20_20110217_PU0206_FD020...
# 2              80  2011_BRP_CCB_S1016_Dep20_20110217_PU0207_FD020...
# 3              80  2011_BRP_CCB_S1016_Dep20_20110217_PU0208_FD020...
# 4              80  2011_BRP_CCB_S1016_Dep20_20110217_PU0209_FD020...
#
#   deployDate  deploymentDepth_Meters dutyCycle_Flag  latitudeDeployed_DecDeg  \
# 0 2011-02-17                    37.2              N                  41.9412
# 1 2011-02-17                    30.5              N                  41.8771
# 2 2011-02-17                    30.9              N                  41.8948
# 3 2011-02-17                    32.1              N                  41.9334
# 4 2011-02-17                    42.1              N                  41.9508
#
#    longitudeDeployed_DecDeg recoveryDate  samplingRate_Hz
# 0                  -70.2880   2011-05-08             5000
# 1                  -70.2540   2011-05-08             5000
# 2                  -70.4439   2011-05-08             5000
# 3                  -70.1859   2011-05-08             5000
# 4                  -70.3901   2011-05-08             5000

# %%
# add between days column, explode out (row for each day)
ccb['between_days'] = ccb.apply(lambda row: pd.date_range(row['deployDate'],row['recoveryDate'],freq='D'), axis=1)
ccb_days = ccb.explode('between_days')
ccb_days
# Out:
#     c_recordOnDays                                     c_uniqueUnitID  \
# 0               71  2011_BRP_CCB_S1016_Dep20_20110217_PU0205_FD020...
# 0               71  2011_BRP_CCB_S1016_Dep20_20110217_PU0205_FD020...
# 0               71  2011_BRP_CCB_S1016_Dep20_20110217_PU0205_FD020...
# 0               71  2011_BRP_CCB_S1016_Dep20_20110217_PU0205_FD020...
# 0               71  2011_BRP_CCB_S1016_Dep20_20110217_PU0205_FD020...
# ..             ...                                                ...
# 37             106   2018_BRP_CCB_S1074_Dep27_20180213_PU0222_FD03178
# 37             106   2018_BRP_CCB_S1074_Dep27_20180213_PU0222_FD03178
# 37             106   2018_BRP_CCB_S1074_Dep27_20180213_PU0222_FD03178
# 37             106   2018_BRP_CCB_S1074_Dep27_20180213_PU0222_FD03178
# 37             106   2018_BRP_CCB_S1074_Dep27_20180213_PU0222_FD03178
#
#    deployDate  deploymentDepth_Meters dutyCycle_Flag  latitudeDeployed_DecDeg  \
# 0  2011-02-17                    37.2              N                41.941200
# 0  2011-02-17                    37.2              N                41.941200
# 0  2011-02-17                    37.2              N                41.941200
# 0  2011-02-17                    37.2              N                41.941200
# 0  2011-02-17                    37.2              N                41.941200
# ..        ...                     ...            ...                      ...
# 37 2018-02-13                     NaN              N                41.937667
# 37 2018-02-13                     NaN              N                41.937667
# 37 2018-02-13                     NaN              N                41.937667
# 37 2018-02-13                     NaN              N                41.937667
# 37 2018-02-13                     NaN              N                41.937667
#
#     longitudeDeployed_DecDeg recoveryDate  samplingRate_Hz between_days
# 0                 -70.288000   2011-05-08             5000   2011-02-17
# 0                 -70.288000   2011-05-08             5000   2011-02-18
# 0                 -70.288000   2011-05-08             5000   2011-02-19
# 0                 -70.288000   2011-05-08             5000   2011-02-20
# 0                 -70.288000   2011-05-08             5000   2011-02-21
# ..                       ...          ...              ...          ...
# 37                -70.237983   2018-05-30             5000   2018-05-26
# 37                -70.237983   2018-05-30             5000   2018-05-27
# 37                -70.237983   2018-05-30             5000   2018-05-28
# 37                -70.237983   2018-05-30             5000   2018-05-29
# 37                -70.237983   2018-05-30             5000   2018-05-30
#
# [3515 rows x 10 columns]

# %% [markdown]
# ### Create new dataframe with test date range (Jan-Feb of 2011)

# %%
# create date range for full time period and add it to dataframe (will test with Jan-Feb 2011)
start_date = '2011-01-01'
end_date = '2011-02-28'

JanFeb2011 = pd.DataFrame({'between_days':pd.date_range(start_date, end_date)})
JanFeb2011.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59 entries, 0 to 58
# Data columns (total 1 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   between_days  59 non-null     datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 600.0 bytes

# %%
# join ccb data to JanFeb date range
JanFeb_ccb = JanFeb2011.merge(ccb_days, on = 'between_days', how = 'left')
JanFeb_ccb
# Out:
#     between_days  c_recordOnDays  \
# 0     2011-01-01             NaN
# 1     2011-01-02             NaN
# 2     2011-01-03             NaN
# 3     2011-01-04             NaN
# 4     2011-01-05             NaN
# ..           ...             ...
# 138   2011-02-28            80.0
# 139   2011-02-28            80.0
# 140   2011-02-28            80.0
# 141   2011-02-28            80.0
# 142   2011-02-28            80.0
#
#                                         c_uniqueUnitID deployDate  \
# 0                                                  NaN        NaT
# 1                                                  NaN        NaT
# 2                                                  NaN        NaT
# 3                                                  NaN        NaT
# 4                                                  NaN        NaT
# ..                                                 ...        ...
# 138  2011_BRP_CCB_S1016_Dep20_20110217_PU0208_FD020... 2011-02-17
# 139  2011_BRP_CCB_S1016_Dep20_20110217_PU0209_FD020... 2011-02-17
# 140  2011_BRP_CCB_S1016_Dep20_20110217_PU0211_FD020... 2011-02-17
# 141  2011_BRP_CCB_S1016_Dep20_20110217_PU0212_FD020... 2011-02-17
# 142  2011_BRP_CCB_S1016_Dep20_20110217_PU0213_FD020... 2011-02-17
#
#      deploymentDepth_Meters dutyCycle_Flag  latitudeDeployed_DecDeg  \
# 0                       NaN            NaN                      NaN
# 1                       NaN            NaN                      NaN
# 2                       NaN            NaN                      NaN
# 3                       NaN            NaN                      NaN
# 4                       NaN            NaN                      NaN
# ..                      ...            ...                      ...
# 138                    32.1              N                  41.9334
# 139                    42.1              N                  41.9508
# 140                    36.4              N                  41.9711
# 141                    40.5              N                  41.9931
# 142                    31.0              N                  41.8762
#
#      longitudeDeployed_DecDeg recoveryDate  samplingRate_Hz
# 0                         NaN          NaT              NaN
# 1                         NaN          NaT              NaN
# 2                         NaN          NaT              NaN
# 3                         NaN          NaT              NaN
# 4                         NaN          NaT              NaN
# ..                        ...          ...              ...
# 138                  -70.1859   2011-05-08           5000.0
# 139                  -70.3901   2011-05-08           5000.0
# 140                  -70.4765   2011-05-08           5000.0
# 141                  -70.2201   2011-05-08           5000.0
# 142                  -70.3412   2011-05-08           5000.0
#
# [143 rows x 10 columns]

# %%
#pd.DataFrame.to_csv(JanFeb_ccb, "./scratch/JanFeb_ccb.csv")

# %% [markdown]
# ### Create example prey data

# %%
# create fake prey data (add between days column, explode out (row for each day))
# (fake prey = Jan03 - Feb03, 2011)
prey_count = 40
prey_start = '2011-01-03'
prey_end = '2011-02-03'

prey = pd.DataFrame({'Transect': prey_transect,
                    'between_days': pd.date_range(prey_start, prey_end)})
prey.head()
# Out:
#    Transect between_days
# 0         2   2011-01-03
# 1         2   2011-01-04
# 2         2   2011-01-05
# 3         2   2011-01-06
# 4         2   2011-01-07

# %% [markdown]
# ### Clean acoustic data

# %%
ccb_days.head()
# Out:
#    c_recordOnDays                                     c_uniqueUnitID  \
# 0              71  2011_BRP_CCB_S1016_Dep20_20110217_PU0205_FD020...
# 0              71  2011_BRP_CCB_S1016_Dep20_20110217_PU0205_FD020...
# 0              71  2011_BRP_CCB_S1016_Dep20_20110217_PU0205_FD020...
# 0              71  2011_BRP_CCB_S1016_Dep20_20110217_PU0205_FD020...
# 0              71  2011_BRP_CCB_S1016_Dep20_20110217_PU0205_FD020...
#
#   deployDate  deploymentDepth_Meters dutyCycle_Flag  latitudeDeployed_DecDeg  \
# 0 2011-02-17                    37.2              N                  41.9412
# 0 2011-02-17                    37.2              N                  41.9412
# 0 2011-02-17                    37.2              N                  41.9412
# 0 2011-02-17                    37.2              N                  41.9412
# 0 2011-02-17                    37.2              N                  41.9412
#
#    longitudeDeployed_DecDeg recoveryDate  samplingRate_Hz between_days
# 0                   -70.288   2011-05-08             5000   2011-02-17
# 0                   -70.288   2011-05-08             5000   2011-02-18
# 0                   -70.288   2011-05-08             5000   2011-02-19
# 0                   -70.288   2011-05-08             5000   2011-02-20
# 0                   -70.288   2011-05-08             5000   2011-02-21

# %%
# select essential columns of acoustic data
Acoustic_clean = ccb_days[['c_uniqueUnitID', 'between_days']]
Acoustic_clean
# Out:
#                                        c_uniqueUnitID between_days
# 0   2011_BRP_CCB_S1016_Dep20_20110217_PU0205_FD020...   2011-02-17
# 0   2011_BRP_CCB_S1016_Dep20_20110217_PU0205_FD020...   2011-02-18
# 0   2011_BRP_CCB_S1016_Dep20_20110217_PU0205_FD020...   2011-02-19
# 0   2011_BRP_CCB_S1016_Dep20_20110217_PU0205_FD020...   2011-02-20
# 0   2011_BRP_CCB_S1016_Dep20_20110217_PU0205_FD020...   2011-02-21
# ..                                                ...          ...
# 37   2018_BRP_CCB_S1074_Dep27_20180213_PU0222_FD03178   2018-05-26
# 37   2018_BRP_CCB_S1074_Dep27_20180213_PU0222_FD03178   2018-05-27
# 37   2018_BRP_CCB_S1074_Dep27_20180213_PU0222_FD03178   2018-05-28
# 37   2018_BRP_CCB_S1074_Dep27_20180213_PU0222_FD03178   2018-05-29
# 37   2018_BRP_CCB_S1074_Dep27_20180213_PU0222_FD03178   2018-05-30
#
# [3515 rows x 2 columns]

# %%
# join clean acoustic data to test (JanFeb) date range
acou_JanFeb = JanFeb2011.merge(Acoustic_clean, on = 'between_days', how = 'left')
acou_JanFeb
# Out:
#     between_days                                     c_uniqueUnitID
# 0     2011-01-01                                                NaN
# 1     2011-01-02                                                NaN
# 2     2011-01-03                                                NaN
# 3     2011-01-04                                                NaN
# 4     2011-01-05                                                NaN
# ..           ...                                                ...
# 138   2011-02-28  2011_BRP_CCB_S1016_Dep20_20110217_PU0208_FD020...
# 139   2011-02-28  2011_BRP_CCB_S1016_Dep20_20110217_PU0209_FD020...
# 140   2011-02-28  2011_BRP_CCB_S1016_Dep20_20110217_PU0211_FD020...
# 141   2011-02-28  2011_BRP_CCB_S1016_Dep20_20110217_PU0212_FD020...
# 142   2011-02-28  2011_BRP_CCB_S1016_Dep20_20110217_PU0213_FD020...
#
# [143 rows x 2 columns]

# %%
# join Acou_JanFeb to fake prey data
CCB_JanFeb = acou_JanFeb.merge(prey, on = 'between_days', how = 'left')
CCB_JanFeb
# Out:
#     between_days                                     c_uniqueUnitID  Transect
# 0     2011-01-01                                                NaN       NaN
# 1     2011-01-02                                                NaN       NaN
# 2     2011-01-03                                                NaN       2.0
# 3     2011-01-04                                                NaN       2.0
# 4     2011-01-05                                                NaN       2.0
# ..           ...                                                ...       ...
# 138   2011-02-28  2011_BRP_CCB_S1016_Dep20_20110217_PU0208_FD020...       NaN
# 139   2011-02-28  2011_BRP_CCB_S1016_Dep20_20110217_PU0209_FD020...       NaN
# 140   2011-02-28  2011_BRP_CCB_S1016_Dep20_20110217_PU0211_FD020...       NaN
# 141   2011-02-28  2011_BRP_CCB_S1016_Dep20_20110217_PU0212_FD020...       NaN
# 142   2011-02-28  2011_BRP_CCB_S1016_Dep20_20110217_PU0213_FD020...       NaN
#
# [143 rows x 3 columns]

# %% [markdown]
# ### Try to list data availability/overlap in one column

# %%
# create a list of our conditions
conditions = [
    (df['likes_count'] <= 2),
    (df['likes_count'] > 2) & (df['likes_count'] <= 9),
    (df['likes_count'] > 9) & (df['likes_count'] <= 15),
    (df['likes_count'] > 15)
    ]

# create a list of the values we want to assign for each condition
values = ['tier_4', 'tier_3', 'tier_2', 'tier_1']

# create a new column and use np.select to assign values to it using our lists as arguments
df['tier'] = np.select(conditions, values)

# display updated DataFrame
df.head()

# %%
# create conditions
conditions = [
        (CCB_JanFeb['c_uniqueUnitID'] == 'NaN') & (CCB_JanFeb['Transect'] == 'NaN'),
        (CCB_JanFeb['c_uniqueUnitID'] != 'NaN') & (CCB_JanFeb['Transect'] != 'NaN'),
        (CCB_JanFeb['c_uniqueUnitID'] == 'NaN') & (CCB_JanFeb['Transect'] != 'NaN'),
        (CCB_JanFeb['c_uniqueUnitID'] != 'NaN') & (CCB_JanFeb['Transect'] == 'NaN')]

# create resulting values for conditions
values = ['No Data', 'Both', 'Prey', 'Acoustic']

# create column to fill
CCB_JanFeb['DataAvailability'] = np.select(conditions, values)

CCB_JanFeb
# Out:
#     between_days                                     c_uniqueUnitID  Transect  \
# 0     2011-01-01                                                NaN       NaN
# 1     2011-01-02                                                NaN       NaN
# 2     2011-01-03                                                NaN       2.0
# 3     2011-01-04                                                NaN       2.0
# 4     2011-01-05                                                NaN       2.0
# ..           ...                                                ...       ...
# 138   2011-02-28  2011_BRP_CCB_S1016_Dep20_20110217_PU0208_FD020...       NaN
# 139   2011-02-28  2011_BRP_CCB_S1016_Dep20_20110217_PU0209_FD020...       NaN
# 140   2011-02-28  2011_BRP_CCB_S1016_Dep20_20110217_PU0211_FD020...       NaN
# 141   2011-02-28  2011_BRP_CCB_S1016_Dep20_20110217_PU0212_FD020...       NaN
# 142   2011-02-28  2011_BRP_CCB_S1016_Dep20_20110217_PU0213_FD020...       NaN
#
#     DataAvailability
# 0               Both
# 1               Both
# 2               Both
# 3               Both
# 4               Both
# ..               ...
# 138             Both
# 139             Both
# 140             Both
# 141             Both
# 142             Both
#
# [143 rows x 4 columns]

# %% [markdown]
# ### Plahts

# %%
# plot prey and acoustic data availability in Jan and Feb
alt.Chart(CCB_JanFeb).mark_rect().encode(
    x = alt.X('between_days:T', timeUnit = 'monthdate'), # dif btwn year(btwn_days) and btwndays, timUnit
    color = 'Transect:N'
).properties(
    width = 500,
    height = 50
).facet(
    row = 'month(between_days)')
# Out:
# alt.FacetChart(...)

# %%
# plot prey and acoustic data availability in Jan and Feb
alt.Chart(CCB_JanFeb).mark_rect().encode(
    x = alt.X('date(between_days):O'), # dif btwn year(btwn_days) and btwndays, timUnit
    color = 'DataAvailability:N'
).properties(
    width = 500,
    height = 50
).facet(
    row = 'month(between_days)')
# Out:
# alt.FacetChart(...)
